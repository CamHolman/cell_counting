# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
AC87 = pd.read_csv('data/sirt6/external/m87e_AC_counts.csv')

# %%
AC87
# Out:
#    Sample (section)  Hemisphere   Location       Tile name  Image name  \
# 0              87-1           1        ctx  tiles_ctx_1(1)           1
# 1              87-1           1        ctx  tiles_ctx_1(1)           2
# 2              87-1           1        ctx  tiles_ctx_1(1)           3
# 3              87-1           1        ctx  tiles_ctx_1(1)           4
# 4              87-1           1        ctx  tiles_ctx_1(1)           5
# 5              87-1           1        ctx  tiles_ctx_1(1)           6
# 6              87-1           1        ctx  tiles_ctx_3(1)           1
# 7              87-1           1        ctx  tiles_ctx_3(1)           2
# 8              87-1           1        ctx  tiles_ctx_3(1)           3
# 9              87-1           1        ctx  tiles_ctx_3(1)           4
# 10             87-1           1        ctx  tiles_ctx_3(1)           5
# 11             87-1           1        ctx  tiles_ctx_3(1)           6
# ...

# %%
import pickle
PIK = "data/sirt6/final/20191217_m87e_counts.pkl"

with open(PIK, "rb") as f:
    CH87 = pickle.load(f)

CH87
# Out:
#  at 0x1b03da4b988>,
# ...

# %%
x = CH87[0]
print(x.name)
print (x.num_cells)
# Out:
# data/sirt6/processed/m87e\MAX_C2-87E_GFAP.1.1000_Iba1.1.1000_10.21.19_20x_zStack_10um_tiles_8(1....1.1000_Iba1.1.1000_10.21.19_20x_zStack_10um_tiles_8(1).czi #1.tif
# 37

# %%
variables = arr[0].keys()
df = pd.DataFrame([[getattr(i,j) for j in variables] for i in arr], columns = variables)

# %%
x.__dict__
# Out:
# {'name': 'data/sirt6/processed/m87e\\MAX_C2-87E_GFAP.1.1000_Iba1.1.1000_10.21.19_20x_zStack_10um_tiles_8(1....1.1000_Iba1.1.1000_10.21.19_20x_zStack_10um_tiles_8(1).czi #1.tif',
#  'image': array([[ 4,  5, 15, ..., 15, 17, 18],
#         [ 4,  7, 15, ..., 14, 15, 17],
#         [ 5,  8, 13, ..., 11, 14, 15],
#         ...,
#         [ 9,  9,  7, ...,  2,  2,  2],
#         [ 8,  8,  7, ...,  2,  2,  2],
#         [ 7,  8,  8, ...,  1,  0,  0]], dtype=uint8),
#  'blobs': array([[498.        , 143.        ,   5.97112393],
#         [487.        , 152.        ,   5.97112393],
#         [463.        ,  12.        ,   5.97112393],
#         [455.        , 358.        ,   5.97112393],
#         [450.        ,  95.        ,   5.97112393],
#         [434.        , 228.        ,   5.97112393],
#         [410.        , 289.        ,   5.97112393],
#         [397.        ,  65.        ,   5.97112393],
#         [395.        , 208.        ,   5.97112393],
# ...

# %%
vars(x)
# Out:
# {'name': 'data/sirt6/processed/m87e\\MAX_C2-87E_GFAP.1.1000_Iba1.1.1000_10.21.19_20x_zStack_10um_tiles_8(1....1.1000_Iba1.1.1000_10.21.19_20x_zStack_10um_tiles_8(1).czi #1.tif',
#  'image': array([[ 4,  5, 15, ..., 15, 17, 18],
#         [ 4,  7, 15, ..., 14, 15, 17],
#         [ 5,  8, 13, ..., 11, 14, 15],
#         ...,
#         [ 9,  9,  7, ...,  2,  2,  2],
#         [ 8,  8,  7, ...,  2,  2,  2],
#         [ 7,  8,  8, ...,  1,  0,  0]], dtype=uint8),
#  'blobs': array([[498.        , 143.        ,   5.97112393],
#         [487.        , 152.        ,   5.97112393],
#         [463.        ,  12.        ,   5.97112393],
#         [455.        , 358.        ,   5.97112393],
#         [450.        ,  95.        ,   5.97112393],
#         [434.        , 228.        ,   5.97112393],
#         [410.        , 289.        ,   5.97112393],
#         [397.        ,  65.        ,   5.97112393],
#         [395.        , 208.        ,   5.97112393],
# ...

# %%
x._desc
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-f9321f7900d4> in <module>
# ----> 1 x._desc
#
# AttributeError: 'cell_counts' object has no attribute '_desc'

# %%
def to_dict(clob):
        return {
            'name': clob.name,
            'image': clob.image,
            'blobs': clob.blobs,
            'pixels_per_micron': clob.pixels_per_micron,
            'num_cells': clob.num_cells,
            'im_area': clob.im_area,
            'slice_area': clob.slice_area,
            'cells_per_area': clob.cells_per_area,
            'percent_slice': clob.percent_slice
            
        }

xd = to_dict(x)
xd
# Out:
# {'name': 'data/sirt6/processed/m87e\\MAX_C2-87E_GFAP.1.1000_Iba1.1.1000_10.21.19_20x_zStack_10um_tiles_8(1....1.1000_Iba1.1.1000_10.21.19_20x_zStack_10um_tiles_8(1).czi #1.tif',
#  'image': array([[ 4,  5, 15, ..., 15, 17, 18],
#         [ 4,  7, 15, ..., 14, 15, 17],
#         [ 5,  8, 13, ..., 11, 14, 15],
#         ...,
#         [ 9,  9,  7, ...,  2,  2,  2],
#         [ 8,  8,  7, ...,  2,  2,  2],
#         [ 7,  8,  8, ...,  1,  0,  0]], dtype=uint8),
#  'blobs': array([[498.        , 143.        ,   5.97112393],
#         [487.        , 152.        ,   5.97112393],
#         [463.        ,  12.        ,   5.97112393],
#         [455.        , 358.        ,   5.97112393],
#         [450.        ,  95.        ,   5.97112393],
#         [434.        , 228.        ,   5.97112393],
#         [410.        , 289.        ,   5.97112393],
#         [397.        ,  65.        ,   5.97112393],
#         [395.        , 208.        ,   5.97112393],
# ...

# %%
yd = to_dict(CH87[1])
yd
# Out:
# {'name': 'data/sirt6/processed/m87e\\MAX_C2-87E_GFAP.1.1000_Iba1.1.1000_10.21.19_20x_zStack_10um_tiles_8(1....1.1000_Iba1.1.1000_10.21.19_20x_zStack_10um_tiles_8(1).czi #2.tif',
#  'image': array([[ 3,  3,  2, ...,  7,  6,  7],
#         [ 4,  4,  3, ...,  7, 10, 11],
#         [ 4,  4,  4, ..., 10, 12, 17],
#         ...,
#         [ 2,  2,  2, ...,  6,  8,  8],
#         [ 2,  2,  2, ...,  6,  7,  8],
#         [ 2,  3,  2, ...,  6,  6,  8]], dtype=uint8),
#  'blobs': array([[511.        , 476.        ,  10.5280343 ],
#         [511.        ,  61.        ,   5.97112393],
#         [484.        , 354.        ,   5.97112393],
#         [482.        , 387.        ,   5.97112393],
#         [470.        , 372.        ,   5.97112393],
#         [465.        , 130.        ,   5.97112393],
#         [464.        , 401.        ,   5.97112393],
#         [461.        , 416.        ,   5.97112393],
#         [459.        , 439.        ,   5.97112393],
# ...

# %%
tdf = pd.DataFrame([xd, yd])

# %%
tdf
# Out:
#                                                 name  \
# 0  data/sirt6/processed/m87e\MAX_C2-87E_GFAP.1.10...
# 1  data/sirt6/processed/m87e\MAX_C2-87E_GFAP.1.10...
#
#                                                image  \
# 0  [[4, 5, 15, 15, 11, 8, 7, 7, 10, 10, 10, 10, 7...
# 1  [[3, 3, 2, 3, 4, 5, 5, 5, 6, 8, 9, 8, 7, 6, 8,...
#
#                                                blobs  pixels_per_micron  \
# 0  [[498.0, 143.0, 5.971123930019734], [487.0, 15...                1.5
# 1  [[511.0, 476.0, 10.528034297666373], [511.0, 6...                1.5
#
#    num_cells        im_area     slice_area  cells_per_area  percent_slice
# 0         37  116508.444444  116474.666667        0.000318      99.971008
# 1         55  116508.444444  116169.333333        0.000473      99.708939

# %%
import os

def clob_to_dict(clob):
        return {
            'name': os.path.basename(clob.name),
            #'image': clob.image,
            #'blobs': clob.blobs,
            'pixels_per_micron': clob.pixels_per_micron,
            'num_cells': clob.num_cells,
            'im_area': clob.im_area,
            'slice_area': clob.slice_area,
            'cells_per_area': clob.cells_per_area,
            'percent_slice': clob.percent_slice
            
        }

xd2 = clob_to_dict(x)
xd2
# Out:
# {'name': 'MAX_C2-87E_GFAP.1.1000_Iba1.1.1000_10.21.19_20x_zStack_10um_tiles_8(1....1.1000_Iba1.1.1000_10.21.19_20x_zStack_10um_tiles_8(1).czi #1.tif',
#  'pixels_per_micron': 1.5,
#  'num_cells': 37,
#  'im_area': 116508.44444444444,
#  'slice_area': 116474.66666666666,
#  'cells_per_area': 0.00031766564403132015,
#  'percent_slice': 99.97100830078125}

# %%
dictlist = []
for i in range(len(CH87)):
    dictlist += [clob_to_dict(CH87[i])]

# %%
dfCH87 = pd.DataFrame(dictlist)
dfCH87
# Out:
#                                                   name  pixels_per_micron  \
# 0    MAX_C2-87E_GFAP.1.1000_Iba1.1.1000_10.21.19_20...                1.5
# 1    MAX_C2-87E_GFAP.1.1000_Iba1.1.1000_10.21.19_20...                1.5
# 2    MAX_C2-87E_GFAP.1.1000_Iba1.1.1000_10.21.19_20...                1.5
# 3    MAX_C2-87E_GFAP.1.1000_Iba1.1.1000_10.21.19_20...                1.5
# 4    MAX_C2-87E_GFAP.1.1000_Iba1.1.1000_10.21.19_20...                1.5
# ..                                                 ...                ...
# 586  MAX_C2-87E_hemi2_GFAP.1.1000_Iba1.1.1000_10.21...                1.5
# 587  MAX_C2-87E_hemi2_GFAP.1.1000_Iba1.1.1000_10.21...                1.5
# 588  MAX_C2-87E_hemi2_GFAP.1.1000_Iba1.1.1000_10.21...                1.5
# 589  MAX_C2-87E_hemi2_GFAP.1.1000_Iba1.1.1000_10.21...                1.5
# 590  MAX_C2-87E_hemi2_GFAP.1.1000_Iba1.1.1000_10.21...                1.5
#
#      num_cells        im_area     slice_area  cells_per_area  percent_slice
# ...

# %%
AC87['Tile name']
# Out:
# 0     tiles_ctx_1(1)
# 1     tiles_ctx_1(1)
# 2     tiles_ctx_1(1)
# 3     tiles_ctx_1(1)
# 4     tiles_ctx_1(1)
# 5     tiles_ctx_1(1)
# 6     tiles_ctx_3(1)
# 7     tiles_ctx_3(1)
# 8     tiles_ctx_3(1)
# 9     tiles_ctx_3(1)
# 10    tiles_ctx_3(1)
# 11    tiles_ctx_3(1)
# 12    tiles_ctx_3(1)
# 13    tiles_ctx_3(1)
# 14    tiles_ctx_3(1)
# 15    tiles_ctx_2(1)
# 16    tiles_ctx_2(1)
# 17    tiles_ctx_2(1)
# 18    tiles_ctx_2(1)
# 19    tiles_ctx_2(1)
# 20    tiles_ctx_2(1)
# 21    tiles_ctx_2(1)
# 22    tiles_ctx_2(1)
# 23    tiles_ctx_2(1)
# 24    tiles_ctx_3(1)
# 25    tiles_ctx_3(1)
# 26    tiles_ctx_3(1)
# 27    tiles_ctx_3(1)
# 28    tiles_ctx_3(1)
# 29    tiles_ctx_3(1)
# 30    tiles_ctx_3(1)
# 31    tiles_ctx_3(1)
# 32    tiles_ctx_3(1)
# 33    hip_tiles_1(1)
# 34    hip_tiles_1(1)
# 35    hip_tiles_1(1)
# 36    hip_tiles_1(1)
# 37    hip_tiles_1(1)
# 38    hip_tiles_1(1)
# 39    hip_tiles_1(1)
# 40    hip_tiles_1(1)
# 41    hip_tiles_1(1)
# 42    hip_tiles_2(1)
# ...

# %%
DF1 = AC87
DF2 = dfCH87

pat = '|'.join(r"{}".format(x) for x in DF1['Tile name'])

DF2['Test3'] = DF2.name.str.extract('('+ pat + ')', expand=False)
DF = pd.merge(DF1, DF2, left_on= 'Tile Name', right_on='Test3').drop('Test3', axis=1)
print (DF)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Test3'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
dfCH87.to_csv('dfCH87.csv')
